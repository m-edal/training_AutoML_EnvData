# %% [markdown]
# <a href="https://colab.research.google.com/github/m-edal/training_AutoML_EnvData/blob/main/JULES_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning for JULES emulation

# %% [markdown]
# Environment: flaml

# %%
# !pip install flaml

# %% [markdown]
# import panckages

# %%
from datetime import time
import xarray as xr
import numpy as np
from flaml import AutoML
import matplotlib.pyplot as plt

# %% [markdown]
# upload the files and read the files

# %%
input = xr.open_dataset("/content/London_StJamesPark_era5_2022_10-2023_12.nc")
output = xr.open_dataset("/content/my_first_run.hourly_output.nc")
input = input.sel(time=output.time)

# %%
input

# %%
output

# %% [markdown]
# Your tasks:
#
# - Upload your JULES input and ouput to current working directory.
# - Use the the former 70% of time as training data, and reset of 30% as testing data, determine how many data are used.
# - Build the ML model: Use the variables in `input` as `AutoML` input, and use the `t1p5m_gb` in the `output` as target.
# - Test the model performance, calculating the `R`, `R2`, `RMSE`, `MBE`
# - Explore the feature importance of AutoML models.
# - Try you best to improve the performance.
# - Plot the results
